# %% [markdown]
# Problem 1
# To prove that the lanes in Germplasm and LocusGene are in the same sequence, I will open both files and then with the function DictReader ignore the header line. After that i will use the function for to create a loop and create a bunch of lists that will place the locus codes of both files together. Finally, I will use the function if to create a conditional that will assess if the locus codes in both files are the same.

# %%
import csv
csvfile = open("LocusGene.tsv", "r")
locusgene_data = csv.DictReader(csvfile, delimiter="\t", quotechar = '"')
csvvfile = open("Germplasm.tsv", "r") 
germplasm_data = csv.DictReader(csvvfile, delimiter="\t", quotechar = '"')             
    
for row in locusgene_data:
    for row in germplasm_data:
        a = [row["Locus"]]
        b = [row["Locus"]]
        print(a+b)    
        if a == b:
            print ("Same sequence")
        else:
            print ("No match!")
            
csvfile.close()
csvvfile.close()
# Out:
# ['AT1G01040', 'AT1G01040']
# Same sequence
# ['AT1G01060', 'AT1G01060']
# Same sequence
# ['AT1G01140', 'AT1G01140']
# Same sequence
# ['AT1G01220', 'AT1G01220']
# Same sequence
# ['AT2G03720', 'AT2G03720']
# Same sequence
# ['AT2G03800', 'AT2G03800']
# Same sequence
# ['AT2G04240', 'AT2G04240']
# Same sequence
# ['AT2G05210', 'AT2G05210']
# Same sequence
# ['AT3G02130', 'AT3G02130']
# Same sequence
# ['AT3G02140', 'AT3G02140']
# Same sequence
# ['AT3G02230', 'AT3G02230']
# Same sequence
# ['AT3G02260', 'AT3G02260']
# Same sequence
# ['AT3G02310', 'AT3G02310']
# Same sequence
# ['AT3G02680', 'AT3G02680']
# Same sequence
# ['AT3G02850', 'AT3G02850']
# Same sequence
# ['AT3G02870', 'AT3G02870']
# Same sequence
# ['AT3G03260', 'AT3G03260']
# Same sequence
# ['AT4G14790', 'AT4G14790']
# Same sequence
# ['AT4G15210', 'AT4G15210']
# Same sequence
# ['AT4G15560', 'AT4G15560']
# Same sequence
# ['AT4G15570', 'AT4G15570']
# Same sequence
# ['AT4G15802', 'AT4G15802']
# Same sequence
# ...

# %% [markdown]
# Problem 2
# To create and design the database i will use the SQL Magic code langague. Each table will have a column with the Locus code that will be the primary key. Then, the LocusGene table will have another two columns, one for the gene and another for the protein length. While the germplasm table will have three more columns: one called germplasm; the phenotype and the last called pubmed.

# %%
# %sql create database germplasm
# %sql use germplasm
# %sql CREATE TABLE Germplasm(agi_locus_code VARCHAR(10) PRIMARY KEY NOT NULL, germplasm VARCHAR(30) NOT NULL, phenotype VARCHAR(500) NOT NULL, pubmed INTEGER NOT NULL)
# %sql CREATE TABLE LocusGene(agi_locus_code VARCHAR(10) PRIMARY KEY NOT NULL, gene VARCHAR(30) NOT NULL, protein_length INTEGER NOT NULL)
# %sql show databases
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 1 rows affected.
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 0 rows affected.
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 0 rows affected.
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 0 rows affected.
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 5 rows affected.
# [('information_schema',),
#  ('germplasm',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %sql DESCRIBE Germplasm
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 4 rows affected.
# [('agi_locus_code', 'varchar(10)', 'NO', 'PRI', None, ''),
#  ('germplasm', 'varchar(30)', 'NO', '', None, ''),
#  ('phenotype', 'varchar(500)', 'NO', '', None, ''),
#  ('pubmed', 'int(11)', 'NO', '', None, '')]

# %%
# %sql DESCRIBE LocusGene
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 3 rows affected.
# [('agi_locus_code', 'varchar(10)', 'NO', 'PRI', None, ''),
#  ('gene', 'varchar(30)', 'NO', '', None, ''),
#  ('protein_length', 'int(11)', 'NO', '', None, '')]

# %% [markdown]
# By describing the two tables I have just created, I can check if I have included all the codes properly.

# %% [markdown]
# Problem 3
# To fill the database, I will use the library pymysql.cursors. First of all, I will connect to the database and open the files to obtein the data. Then I will use the function try folloed by with and for to create a loop and be able to insert all of the data in both tables.

# %%
import pymysql.cursors
import csv
locusfile = open("LocusGene.tsv", "r")
locusgene_data = csv.DictReader(locusfile, delimiter="\t", quotechar = '"')
germfile = open("Germplasm.tsv", "r") 
germplasm_data = csv.DictReader(germfile, delimiter="\t", quotechar = '"')
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasm',
                             charset='utf8mb4',  
                             cursorclass=pymysql.cursors.DictCursor)
try:
    with connection.cursor() as cursor:
        for row in locusgene_data:
            sql = """INSERT INTO LocusGene (agi_locus_code, gene, protein_length)
            VALUES ('{}', '{}', '{}')""".format(row["Locus"], row["Gene"], row["ProteinLength"])
            cursor.execute(sql)
        for row in germplasm_data:
            sql = """INSERT INTO Germplasm (agi_locus_code, germplasm, phenotype, pubmed)
            VALUES ('{}', '{}', '{}', '{}')""".format(row["Locus"], row["germplasm"], row["phenotype"], row["pubmed"])
            cursor.execute(sql)
    connection.commit()
finally:
    print("")

# %%
locusfile.close()
germfile.close()
connection.close()

# %%
# %sql SELECT * FROM LocusGene
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 32 rows affected.
# [('AT1G01040', 'DCL1', 332),
#  ('AT1G01060', 'LHY', 290),
#  ('AT1G01140', 'CIPK9', 223),
#  ('AT1G01220', 'FKGP', 190),
#  ('AT2G03720', 'MRH6', 189),
#  ('AT2G03800', 'GEK1', 196),
#  ('AT2G04240', 'XERICO', 256),
#  ('AT2G05210', 'POT1A', 221),
#  ('AT3G02130', 'RPK2', 284),
#  ('AT3G02140', 'TMAC2', 300),
#  ('AT3G02230', 'RGP1', 301),
#  ('AT3G02260', 'BIG', 279),
#  ('AT3G02310', 'SEP2', 175),
#  ('AT3G02680', 'NBS1', 190),
#  ('AT3G02850', 'SKOR', 234),
#  ('AT3G02870', 'VTC4', 311),
#  ('AT3G03260', 'HDG8', 194),
#  ('AT4G14790', 'SUV3', 312),
#  ('AT4G15210', 'BAM5', 313),
#  ('AT4G15560', 'DXS', 219),
#  ('AT4G15570', 'MAA3', 294),
#  ('AT4G15802', 'HSBP', 254),
#  ('AT4G15880', 'ESD4', 265),
#  ('AT4G16420', 'ADA2B', 279),
#  ('AT4G16480', 'INT4', 284),
#  ('AT5G10480', 'PAS2', 301),
#  ('AT5G10510', 'AIL6', 310),
#  ('AT5G11110', 'SPS2', 232),
#  ('AT5G11260', 'HY5', 221),
# ...

# %%
# %sql SELECT * FROM Germplasm
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 32 rows affected.
# [('AT1G01040', 'CS3828', 'Increased abundance of miRNA precursors.', 17369351),
#  ('AT1G01060', 'lhy-101', 'The mutant plants are hypersensitive to both FRc and Rc light treatments in hypocotyl elongation and exhibits a small reciprocal enlargement in cotyledon area, albeit not statistically significant.', 16891401),
#  ('AT1G01140', 'SALK_058629', 'hypersensitive to low potassium media', 17486125),
#  ('AT1G01220', 'SALK_012400C', 'fkgp-1 mutants have about 40 times more L-fucose than wild type Arabidopsis plants, but the levels of other monosaccharides do not appear to differ s ... (41 characters truncated) ... henotypic abnormalities were observed in the fkgp-1 mutants, nor were any differences in the sugar composition of cell wall polysaccharides detected.', 18199744),
#  ('AT2G03720', 'SALK_042433', 'Multiple straight hairs', 16367956),
#  ('AT2G03800', 'gek1-1', 'Ethanol hypersensitivity.', 15215505),
# ...

# %% [markdown]
# With SQL Magic and the select function I can check if all the information has been added to the database correctly.

# %% [markdown]
# Problem 4
# To complete reports 1 and 2 I will use the library pymysql.cursors. For report 1 I will connect to the database and then join both tables indicating that the locus codes are the same. For report 2 I will select both tables and the functions AND and OR to select the genes SKOR and MAA3 in particular.

# %%
#report 1
import pymysql.cursors
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasm',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
try:
    with connection.cursor() as cursor:
        sql = """SELECT g.*, l.* FROM Germplasm g INNER JOIN LocusGene l ON
        g.agi_locus_code = l.agi_locus_code"""
        cursor.execute(sql)
        results = cursor.fetchall()
        print("\nagi_locus_code\t germplasm\t phenotype\t\t pubmed\t\t gene\t protein_length\n")
        for result in results:
            print(result['agi_locus_code'], "\t", result['germplasm'], "\t", result['phenotype'], "\t", result['pubmed'], "\t", result['gene'], "\t", result['protein_length'], "\n")
finally:
    print("")
    connection.close()
# Out:
# agi_locus_code	 germplasm	 phenotype		 pubmed		 gene	 protein_length
#
# AT1G01040 	 CS3828 	 Increased abundance of miRNA precursors. 	 17369351 	 DCL1 	 332
#
# AT1G01060 	 lhy-101 	 The mutant plants are hypersensitive to both FRc and Rc light treatments in hypocotyl elongation and exhibits a small reciprocal enlargement in cotyledon area, albeit not statistically significant. 	 16891401 	 LHY 	 290
#
# AT1G01140 	 SALK_058629 	 hypersensitive to low potassium media 	 17486125 	 CIPK9 	 223
#
# AT1G01220 	 SALK_012400C 	 fkgp-1 mutants have about 40 times more L-fucose than wild type Arabidopsis plants, but the levels of other monosaccharides do not appear to differ significantly in the mutants. No obvious phenotypic abnormalities were observed in the fkgp-1 mutants, nor were any differences in the sugar composition of cell wall polysaccharides detected. 	 18199744 	 FKGP 	 190
#
# AT2G03720 	 SALK_042433 	 Multiple straight hairs 	 16367956 	 MRH6 	 189
#
# ...

# %%
#report 2
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasm',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
connection.autocommit(True)

try:
    with connection.cursor() as cursor:
        sql = """SELECT * FROM Germplasm, LocusGene WHERE 
        LocusGene.agi_locus_code = Germplasm.agi_locus_code AND (LocusGene.gene = 'SKOR' OR LocusGene.gene = 'MAA3')"""
        cursor.execute(sql)
        results = cursor.fetchall() 
        print("\nagi_locus_code\t germplasm\t phenotype\t pubmed\t gene\t protein_length\n")
        for result in results:
            print(result['agi_locus_code'], "\t", result['germplasm'], "\t", result['phenotype'], "\t", result['pubmed'], "\t", result['gene'], "\t", result['protein_length'], "\n")

finally:
    print("")
connection.close()
# Out:
# agi_locus_code	 germplasm	 phenotype	 pubmed	 gene	 protein_length
#
# AT3G02850 	 CS3816 	 The skor-1 mutant is sensitive to toxic cations in addition to K+ depletion. 	 17568770 	 SKOR 	 234
#
# AT4G15570 	 maa3 	 Homozygotes are not recovered. Female gametophyte development is delayed and asynchronous. During fertilization, fusion of polar nuclei does not occur. Polar nuclei nucloeli are smaller than WT. 	 18772186 	 MAA3 	 294

# %%
#report 3
import re
import pymysql.cursors
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasm',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)


connection.autocommit(True)
a = 1
for a in range (1,6):
    with connection.cursor() as cursor:
        try:
            sql = "SELECT agi_locus_code FROM Germplasm WHERE agi_locus_code LIKE 'AT[1,6]G\d+'"
            cursor.execute(sql)
            results = cursor.fetchall() 
            print(results)


        finally:
            print("")
#connection.close()
# Out:
# ()
#
# ()
#
# ()
#
# ()
#
# ()
